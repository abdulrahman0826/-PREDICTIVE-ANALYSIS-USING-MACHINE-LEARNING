# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv("C:/Users/LENOVO/Downloads/House-Price-Prediction-clean.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  ...  WoodDeckSF  OpenPorchSF  \
# 0         706        150          856  ...           0           61
# 1         978        284         1262  ...         298            0
# 2         486        434          920  ...           0           42
# 3         216        540          756  ...           0           35
# 4         655        490         1145  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
data.tail()
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  ...  WoodDeckSF  \
# 1455          2000           0        953          953  ...           0
# 1456          1988         790        589         1542  ...         349
# 1457          2006         275        877         1152  ...           0
# 1458          1996          49          0         1078  ...         366
# 1459          1965         830        136         1256  ...         736
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF',
#        '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
data.shape
# Out:
# (1460, 32)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  ...  WoodDeckSF  \
# ...

# %%
data.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# BsmtFinSF1       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# GrLivArea        0
# BsmtFullBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
data.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  ...  WoodDeckSF  OpenPorchSF  \
# 0         706        150          856  ...           0           61
# 1         978        284         1262  ...         298            0
# 2         486        434          920  ...           0           42
# 3         216        540          756  ...           0           35
# 4         655        490         1145  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
sns.relplot(x='SalePrice',y='WoodDeckSF',data=data)

# %%
sns.relplot(x='SalePrice',y='YearBuilt',data=data)

# %%
sns.relplot(x='SalePrice',y='WoodDeckSF',hue='BsmtUnfSF',data=data)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train = data.drop(['SalePrice','WoodDeckSF','YearBuilt'],axis=1)
test = data['SalePrice']

# %%
x_train, x_test, y_train, y_test = train_test_split(train,test,test_size=0.3,random_state=2)

# %%
regr =LinearRegression()

# %%
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred=regr.predict(x_test)

# %%
pred
# Out:
# array([293167.01423462, 175042.80851454, 312569.34554189, 232248.89637702,
#        216018.45270389, 203068.85457643, 232587.27668303, 207031.72658415,
#        124265.18240205, 337774.71688131, 248705.24594414, 216258.25037234,
#        115742.4391187 , 149225.75995806,  84435.13135765, 249535.75757038,
#        269829.03318285, 325907.07380222, 239046.80648692, 321656.93781766,
#        321096.00903037, 156405.02082817, 186926.05330263, 229986.73589444,
#        362182.34787798, 248482.6746948 , 166151.31815197, 283627.56634743,
#        223763.44407716, 379825.41278994, 305151.77265516, 175056.81790233,
#        276935.41225019, 118027.51725396, 202572.65044131, 223947.39427859,
#        159324.90350197, 313680.62822773, 323632.52620268, 380616.03760007,
#        169957.69028894, 220289.90341133, 150268.78389475,  80868.82430397,
#         93183.88547813, 235710.90931729,  56586.12517563, 160679.74284566,
# ...

# %%
regr.score(x_test,y_test)
# Out:
# 0.533661075996969
